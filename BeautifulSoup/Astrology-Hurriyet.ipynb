# %%
import bs4
from bs4 import BeautifulSoup as soup  # HTML data structure
from urllib.request import urlopen as uReq  # Web client

# %%
# URl to web scrap from.
# in this example we web scrap graphics cards from Newegg.com
page_url = "https://www.hurriyet.com.tr/mahmure/astroloji/koc-burcu/"

# %%
# opens the connection and downloads html page from url
uClient=uReq(page_url)
uClient

# %%
page_html=uClient.read()
page_html
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charset="utf-8"><title>Ko\xc3\xa7 Burcu 2020 - G\xc3\xbcnl\xc3\xbck Yorum, Bug\xc3\xbcn i\xc3\xa7in A\xc5\x9fk, Sa\xc4\x9fl\xc4\xb1k, Para Yorumlar\xc4\xb1</title><link rel="shortcut icon" href="/mahmurefavicon.ico" /><meta itemprop="image" content="https://i4.hurimg.com/i/hurriyet/75/620x350/57bbf91967b0a930747c6900" /><meta property="fb:app_id" content="244990652332251" /><meta property="fb:admins" content="100000280173740" /><meta property="literal-category" content="Bur&#231;lar" /><meta property="og:url" content="http://www.hurriyet.com.tr/mahmure/astroloji/koc-burcu/" /><meta name="twitter:url" content="http://www.hurriyet.com.tr/mahmure/astroloji/koc-burcu/" /><link href=" //s.hurriyet.com.tr/static/styles/mahmure/homepage.min.css?v=octo-18.39.0.1026" rel="stylesheet" /><link rel="canonical" href="https://www.hurriyet.com.tr/mahmure/astroloji/koc-burcu/" /><link rel="amphtml" href="https://www.hurriyet.com.tr/amp/mahmure/astroloji/koc-burcu/" /><meta property="og:title" content="Ko\xc3\xa7 Burcu G\xc3\xbcnl\xc3\xbck Yorumu" /><meta property="og:type" content="article" /><meta property="og:image" content="https://s.hurriyet.com.tr/static/images/mahmure/horoscopelogos/koc-kirmizi.png" /><meta property="og:description" content="Kariyerinizle ilgili hesapta olmayan baz\xc4\xb1 sorunlar ya\xc5\x9fayabilirsiniz." /><meta property="og:site_name" content=" mahmure.hurriyet.com.tr/astroloji" /><meta property="og:image:width" content="400"><meta property="og:image:height" content="400"><meta name="twitter:card" content=" summary" /><meta name="twitter:site" content=" @mahmurecom" /><meta name="twitter:title" content="Ko\xc3\xa7 Burcu G\xc3\xbcnl\xc3\xbck Yorumu" /><meta name="twitter:description" content="Mahmure Bur\xc3\xa7 Detay Sayfas\xc4\xb1" /><meta name="twitter:image" content="https://s.hurriyet.com.tr/static/images/mahmure/horoscopelogos/koc-kirmizi.png" /><meta name="twitter:domain" content="mahmure.com" /><meta name="description" content="Ko\xc3\xa7 Burcu olan ki\xc5\x9fileri bug\xc3\xbcn neler bekliyor? Ko\xc3\xa7 kad\xc4\xb1n\xc4\xb1 ve ko\xc3\xa7 erke\xc4\x9fi i\xc3\xa7in bug\xc3\xbcn a\xc5\x9fk hayat\xc4\xb1 nas\xc4\xb1l ge\xc3\xa7ecek, para ve sa\xc4\x9fl\xc4\xb1k durumu nas\xc4\xb1l olacak? Astroloji uzmanlar\xc4\xb1 taraf\xc4\xb1ndan yaz\xc4\xb1lan bug\xc3\xbcnk\xc3\xbc bur\xc3\xa7 yorumlar\xc4\xb1n\xc4\xb1 ve ko\xc3\xa7 burcu hakk\xc4\xb1nda di\xc4\x9fer t\xc3\xbcm merak edilenleri Mahmure\'nin 2020 ko\xc3\xa7 burcu sayfas\xc4\xb1nda bulabilirsiniz." /><meta name="keywords" content="" /><meta name="medyanet:keywords" content="" /><link rel="image_src" href="https://s.hurriyet.com.tr/static/images/mahmure/horoscopelogos/koc-kirmizi.png" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no,user-scalable=no"><script type="text/javascript" async src="//app.medyanetads.com/dfp.js" id="medyanet"></script><script type="text/javascript" src="//s.hurriyet.com.tr/static/scripts/mahmure/hurriyet.mahmure-app.min.js?v=octo-18.39.0.1026"></script><!--Video player scripts--><script type="text/javascript" src="//gatr.hit.gemius.pl/gplayer.js" async></script><script src="//imasdk.googleapis.com/js/sdkloader/ima3.js" type="text/javascript"></script><script src="//s.duhnet.tv/q/s/player/html5/1.20.2/assets/js/docs.min.js" type="text/javascript"></script><script src="//s.hurriyet.com.tr/static/quark-player-maestro/js/maestro-plugins.min.js?v=octo-18.39.0.1026" type="text/javascript"></script><!--Video player scripts end--><!--Multi video onscroll play--><script type="text/javascript">if (typeof hurriyetAsyncLoader === "undefined") {var hurriyetAsyncLoader = {};hurriyetAsyncLoader.ready = function(arg, cb) {return cb();}}if (typeof jQuery !== "undefined") {$(function () {hurriyetAsyncLoader.ready(\'async_videoLibJs\', function() {/*E\xc4\x9fer Exception sayfalarindan birindeysek kontrollerin hi\xc3\xa ...

# %%
# parses html into a soup data structure to traverse html
# as if it were a json data type.
page_soup = soup(page_html, "html.parser")
page_soup.p
# Out:
# <p class="gm-connect-title">HÜRRİYET'E BAĞLI KAL</p>

# %%
page_soup.body.span
# Out:
# <span class="gm-btn"><i class="fa fa-search"></i></span>

# %%
# finds each product from the store page
containers = page_soup.findAll("div", {"class": "horoscope-detail-tab-content"})
#containers = page_soup.findAll("div", {"class": "item-container"})
len(containers)
# Out:
# 1

# %%
container=containers[0]
container
# Out:
# <div class="horoscope-detail-tab-content"><p>Kariyerinizle ilgili hesapta olmayan bazı sorunlar yaşayabilir ve bunlara kalıcı bir çözüm bulmakta zorlanabilirsiniz. Aslında şu an yaşadığınız sorunlar geçmişte üstünü örtüp pek ilgilenmediğiniz konularda olabilir. Temkinli olun.</p></div>

# %%
koc=container.text ##style text de

# %%
koc
# Out:
# 'Kariyerinizle ilgili hesapta olmayan bazı sorunlar yaşayabilir ve bunlara kalıcı bir çözüm bulmakta zorlanabilirsiniz. Aslında şu an yaşadığınız sorunlar geçmişte üstünü örtüp pek ilgilenmediğiniz konularda olabilir. Temkinli olun.'

# %%
uClient.close()
